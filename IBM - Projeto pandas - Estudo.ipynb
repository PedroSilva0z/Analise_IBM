# %% [markdown]
# ## O dataset
#
# O dataset a ser utilizado é o *IBM HR Analytics Employee Attrition & Performance*, disponível no Kaggle. O dataset contém informações sobre funcionários de uma empresa fictícia, como idade, gênero, estado civil, nível de satisfação, entre outros. O objetivo é prever a probabilidade de um funcionário sair da empresa.
#
# [Link do Kaggle](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset/data)
#
# Os termos *attrition* ("atrito") e *turnover* ("rotatividade") são frequentemente usados de forma intercambiável no contexto de recursos humanos e gestão de força de trabalho, mas eles se referem a conceitos ligeiramente diferentes em relação às mudanças no número e na composição dos empregados dentro de uma organização. Compreender a distinção entre esses dois é importante para analisar e relatar com precisão a dinâmica da força de trabalho.
#
# ### Atrito
#
# Atrito refere-se à redução gradual de empregados por meio de circunstâncias naturais, como aposentadoria, demissão voluntária por motivos pessoais, ou a decisão de não substituir empregados que estão de saída. Atrito pode levar a uma diminuição no tamanho da força de trabalho, mas é caracterizado por sua natureza voluntária e muitas vezes incontrolável. Organizações podem permitir o atrito para reduzir o tamanho de sua força de trabalho sem recorrer a demissões, vendo isso como uma forma menos disruptiva de ajustar seus níveis de pessoal.
#
# Em análises, quando você está analisando um conjunto de dados para atrito, você frequentemente olha para as razões por trás das saídas voluntárias e a taxa na qual estas ocorrem naturalmente ao longo do tempo. Taxas de atrito podem fornecer insights sobre a satisfação dos empregados e tendências de longo prazo da força de trabalho.
#
# ### Rotatividade
#
# Rotatividade, por outro lado, engloba um escopo mais amplo de partidas de empregados, incluindo tanto renúncias voluntárias quanto demissões involuntárias (como demissões ou términos por justa causa). Porém, ocorre a substituição da força de trabalho. Rotatividade é uma medida de quantos empregados estão deixando a companhia por qualquer motivo. Uma alta taxa de rotatividade pode indicar problemas com satisfação no trabalho, cultura do local de trabalho, ou estabilidade organizacional, e frequentemente requer ação da gestão para endereçar as causas subjacentes.
#
# Rotatividade é calculada dividindo o número de empregados que saem pelo número médio de empregados, geralmente em uma base anual, e expressando isso como uma porcentagem. Esta métrica é crucial para entender como as saídas de empregados, tanto voluntárias quanto involuntárias, afetam a capacidade da organização de manter uma força de trabalho estável e eficaz.
#
# ### Diferenças Chave
#
# - **Natureza**: Atrito geralmente é voluntário e pode ser devido a fatores naturais ou incontroláveis, enquanto rotatividade inclui tanto saídas voluntárias quanto demissões involuntárias.
# - **Implicações para Gestão**: Atrito pode ser parte de uma estratégia de ajuste natural da força de trabalho e nem sempre é negativo, enquanto alta rotatividade é frequentemente um sinal de problemas dentro da organização que precisam ser abordados.
# - **Foco Estratégico**: Análise de atrito pode focar em entender tendências de longo prazo da força de trabalho e planejamento de aposentadoria, enquanto análise de rotatividade é frequentemente usada para identificar questões imediatas com satisfação de empregados, engajamento, ou práticas de gestão que podem estar impactando a retenção de staff.
#
# Enquanto ambos atrito e rotatividade lidam com empregados deixando a organização, eles diferem em seu escopo e as implicações estratégicas para gerenciar e entender a dinâmica da força de trabalho. No seu conjunto de dados de empregados, distinguir entre atrito e rotatividade pode ajudar na customização de estratégias para planejamento da força de trabalho, retenção e desenvolvimento organizacional.

# %% [markdown]
# |    | Name                       | Description                                                                                                                                                    |
# |---:|:---------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | Age                        | Numerical Value                                                                                                                                                |
# |  1 | Attrition                  | Employee leaving the company - Text - No, Yes                                                                                                                     |
# |  2 | BusinessTravel            | Text - Non-Travel, Travel_Frequently, Travel_Rarely                                                                                                             |
# |  3 | DailyRate                 | Numerical Value - Salary Level                                                                                                                                 |
# |  4 | Department                 | Text - Sales, Research & Development, Human Resources                                                                                                         |
# |  5 | DistanceFromHome         | Numerical Value - the distance from work to home in miles
# |  6 | Education                  | Numerical Value - 1=Below college, 2=College, 3=Bachelor, 4=Master, 5=PhD   |
# |  7 | EducationField            | Text - Life Sciences, Medical, Marketing, Techincal Degree, Human Resources, Other                                                                                   |
# |  8 | EmployeeCount             | Numerical Value - 1                                                                                                                                               |
# |  9 | EmployeeNumber            | Numerical Value - Employee ID                                                                                                                                  |
# | 10 | EnvironmentSatisfaction    | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High |
# | 11 | Gender                     | Text - Female, Male                                                                                                                                             |
# | 12 | HourlyRate                | Numerical Value - Hourly Salary                                                                                                                                |
# | 13 | JobInvolvement            | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 14 | JobLevel                  | Numerical Value - 1, 2, 3, 4, 5. Means different job levels                                                                                                     |
# | 15 | JobRole                   | Text - Sales Executive, Research Scientist, Laboratory Technician, Manufacturing Director, Healthcare Representative, Manager, Sales Representative, Research Director, Human Resources |
# | 16 | JobSatisfaction           | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 17 | MaritalStatus             | Text - Single, Married, Divorced                                                                                                                                      |
# | 18 | MonthlyIncome             | Numerical Value - Monthly Salary                                                                                                                               |
# | 19 | MonthlyRate                | Numerical Value - Monthly Rate                                                                                                                                  |
# | 20 | NumCompaniesWorked        | Numerical Value - Number of companies worked at                                                                                                                |
# | 21 | Over18                    | Text - Y                                                                                                                                                    |
# | 22 | Overtime                   | Text - No, Yes                                                                                                                                                    |
# | 23 | PercentSalaryHike        | Numerical Value - Percentage increase in salary                                                                                                                |
# | 24 | PerformanceRating         | Numerical Value - 1=Low, 2=Good, 3=Excellent, 4=Outstanding                                                                                                    |
# | 25 | RelationshipSatisfaction  | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 26 | StandardHours             | Numerical Value - 80                                                                                                                                            |
# | 27 | StockOptionsLevel        | Numerical Value - 0, 1, 2, 3                                                                                                                                    |
# | 28 | TotalWorkingYears        | Numerical Value - Total years worked                                                                                                                            |
# | 29 | TrainingTimesLastYear   | Numerical Value - How many times the employee has been trained last year                                                                                       |
# | 30 | WorkLifeBalance          | Numerical Value - 1=Bad, 2=Good, 3=Better, 4=Best                                                                                                              |
# | 31 | YearsAtCompany           | Numerical Value - Number of years at the company                                                                                                                |
# | 32 | YearsInCurrentRole      | Numerical Value -Number of years in current role                                                                                                                |
# | 33 | YearsSinceLastPromotion | Numerical Value - Years since last promotion                                                                                                                    |
# | 34 | YearsWithCurrManager | Numerical Value - Years with current manager                                                                                                                    |

# %% [markdown]
# ## Checagens básicas

# %% [markdown]
# - shape
# - colunas
# - tipos
# - valores nulos
# - valores "estranhos"
# - valores únicos
# - valores duplicados
# - contagem de valores relevantes

# %%
from pandas import read_csv, option_context, crosstab, options

# %%
options.display.float_format = '{:_.2f}'.format

# %%
base = read_csv('employee_attrition.csv')
base.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# <br><br>
# ## Quantidade de linhas e colunas da base

# %%
base.shape
# Out:
# (1470, 35)

# %% [markdown]
# <br><br>
# ## Nome das colunas

# %%
base.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# <br><br>
# ## Informações das colunas
# - Contagem de valores preenchidos
# - Tipo da coluna

# %%
 base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# <br><br>
# ## Verificação de valores nulos

# %%
 base.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# <br><br>
# ## Verificação de linhas duplicadas

# %%
base.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <br><br>
# ## Realizando a contagem de repetições para as colunas de Objeto (strings)

# %%
# for item in base.describe(exclude='number'):
#     print(item, '\n ', base[item].unique(), '\n')
    
for col in base.select_dtypes(include=['object']).columns:
    print(f"Unique values in column '{col}':\n{base[col].value_counts()}\n")
# Out:
# Unique values in column 'Attrition':
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
#
# Unique values in column 'BusinessTravel':
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
#
# Unique values in column 'Department':
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
#
# Unique values in column 'EducationField':
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
#
# Unique values in column 'Gender':
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
#
# Unique values in column 'JobRole':
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# ...

# %% [markdown]
# <br><br>
# ## Mostrando todas as colunas do DataFrame, sme as reticências que resumem

# %%
with option_context('display.max_columns', base.shape[1]):
    display(base.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# <br><br>
# ## Explorando as colunas de valores
#
# - Podemos olhar pontos interessantes nessa tabela resultante do describe: <br>
#     - Comparar as colunas olhando o mínimo e máximo, se for, por exemplo, uma coluna de idade seria estranho ter um resultado minimo de 10 para trabalhadores.
#     - O Desvio padrão: caso o resultado seja 0, significa que não tem nenhum desvio nos dados, sendo assim temos valor único. (não sendo útil para uma determinada análise)

# %%
with option_context('float_format', '{:.2f}'.format, 'display.max_columns', base.shape[1]):
    display(base.describe())
# Out:
#           Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count 1470.00    1470.00           1470.00    1470.00        1470.00
# mean    36.92     802.49              9.19       2.91           1.00
# std      9.14     403.51              8.11       1.02           0.00
# min     18.00     102.00              1.00       1.00           1.00
# 25%     30.00     465.00              2.00       2.00           1.00
# 50%     36.00     802.00              7.00       3.00           1.00
# 75%     43.00    1157.00             14.00       4.00           1.00
# max     60.00    1499.00             29.00       5.00           1.00
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count         1470.00                  1470.00     1470.00         1470.00
# mean          1024.87                     2.72       65.89            2.73
# std            602.02                     1.09       20.33            0.71
# ...

# %% [markdown]
# - Teste do cálculo abaixo para exemplificar
#
#     - Columns Age

# %%
Q1 = 30
Q2 = 36
Q3 = 43

valor_metrica = 1.5

# Descobrindo o valor minimo para ser considerado um OUTLIER
print(Q1 - valor_metrica * (Q3 - Q1))

# Descobrindo o valor máximo para ser considerado um OUTLIER
print(Q3 + valor_metrica * (Q3 - Q1))
# Out:
# 10.5
# 62.5

# %% [markdown]
# #### CONCLUSÃO
#
# - Dentro da idade mínima e máxima, não tem nenhum dado menor que 10.5 e nem maior que 62.5

# %% [markdown]
#     - Columns DistanceFromHome

# %%
Q1 = 2
Q2 = 7
Q3 = 14

valor_metrica = 1.5

# Descobrindo o valor minimo para ser considerado um OUTLIER
print(Q1 - valor_metrica * (Q3 - Q1))

# Descobrindo o valor máximo para ser considerado um OUTLIER
print(Q3 + valor_metrica * (Q3 - Q1))
# Out:
# -16.0
# 32.0

# %% [markdown]
# ### CONCLUSÃO
#
#     - Mesmo a definição do máximo sendo bem discrepante dos quartils, ainda o valor máximo não é outiler segundo o cálculo

# %% [markdown]
#     - Columns TotalWorkingYears

# %%
Q1 = 6
Q2 = 10
Q3 = 15

valor_metrica = 1.5

# Descobrindo o valor minimo para ser considerado um OUTLIER
print(Q1 - valor_metrica * (Q3 - Q1))

# Descobrindo o valor máximo para ser considerado um OUTLIER
print(Q3 + valor_metrica * (Q3 - Q1))
# Out:
# -7.5
# 28.5

# %% [markdown]
# ### CONCLUSÃO
#
#     - Nesse caso, já vemos valores OUTLIERS. Número máximo do cálculo = 28.5, sendo o máximo na coluna = 40
#
#     - Isso não necessáriamente indica um erro na base, precisa de mais critérios e outras análises especificas de outliers

# %% [markdown]
# <br><br>
# # Explicando quartis e Outliers
#
# #### Quartis
#
# Quartis são valores que dividem um conjunto de dados em 4 parte iguais. O primeiro quartil (Q1) é o valor que deixa 25% dos dados abaixo e 75% acima.
# O 2º quartil (Q2) é a mediana, que deixa 50% dos dados abaixo e 50% dos dados acima.
# O 3º quaritl (Q3) deixa 75% dos valores abaixo e 25% acima.
#
# Por exemplo, se temos um conjunto de dados com 100 valores, o 1º quartil será o valor que deixa 25 valores abaixo e 75 acima.
# O 2º quartil será o valor que deixa 50 valores abaixo e 50 acima.
# O 3º quartil será o valor que deixa 75 valores abaixo e 25 acima.
#
#
# ### Outliers
#
# Outliers são valores que fogem do padrão do conjunto de dados. São valores muito altos ou muito baixos que podem influenciar negativamente na análise dos dados.
# Por exemplo, se temos um conjunto de dados com salários de funcionários de uma empresa, e um dos salários é muito maior que os outros, esse salário pode ser considerado um outlier.
#
# Estatiscamente, um outlier é um valor que está a mais de 1,5 vezes o intervalo interquartil acima do 3º quartil (Q3) ou mais de 1,5 vezes o intervalo interquartil abaixo do primeiro (Q1). O intervalo interquartil é a diferença entre o terceiro quartil (Q3) e o primeiro quartil (Q1)

# %% [markdown]
# <br><br><br><br>
# ## Verificar o describe para colunas não númericas
#
# <br>

# %%
base.describe(exclude='number')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %% [markdown]
# OBS: O dataset é desbalanceado, ou seja, quantidade de funcionários que saíram da empresa é muito menos que a quantidade de funcionários que permanceram na empresa. Isso pode influenciar na análise de dados, **principalmente se for um modelo de machine learning, por ter muitos mais "não" do que "sim". Podendo ficar tendencioso.**<br>
# (É preciso fazer um rebalanceamento para usar ML)
#
# A coluna 'Attrition' é a coluna que indica se o funcionário saiu da emprea ou não. Ela é a coluna alvo, ou taget. Sendo essa a coluna que queremos avaliar e prever.

# %% [markdown]
# <br><br><br><br>
#
# ##### Remover colunas com valores únicos
# ##### Encontrar registros dos 10 funcionários mais velhos e dos 10 mais novos
# ##### Encontrar os registros dos 10 funcionários com mais tempo de empresa e dos 10 com menos tempo
# ##### Encontrar os registros dos 10 funcionários com mais tempo no cargo (sem promoção) e dos 10 com menos tempo
# ##### Agrupamento (além dos descritos, mostrar também o gruop por saída ou não dos funcionários)
# - Contagem de funcionários por departamento
# - Média de salário por departamento
# - Gênero por departamento
# - Gênero por cargo
# - Média de salário por cargo
# - Média de salário por cargo e nível
# - Contagem de gênero por departamento
# - Média de salário por nível eduacaional
# <br><br>

# %%
# Verificar se o ID, se repete nos casos, caso o tenha, irá aparecer um resultado diferente do total da base
print(base.EmployeeNumber.nunique())

base = base.drop(['EmployeeNumber', 'StandardHours', 'Over18', 'EmployeeCount'], axis=1)
# Out:
# 1470

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %% [markdown]
# ## 10 funcionários mais velhos e dos 10 mais novos¶

# %%
display(base.nlargest(10, 'Age'))

display(base.nsmallest(10, 'Age'))
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 63     59        No      Travel_Rarely       1435                   Sales
# 70     59        No  Travel_Frequently       1225                   Sales
# 105    59        No         Non-Travel       1420         Human Resources
# 225    59        No      Travel_Rarely        142  Research & Development
#
#       DistanceFromHome  Education   EducationField  EnvironmentSatisfaction  \
# 411                  7          3    Life Sciences                        1
# ...

# %% [markdown]
# ## 10 funcionários com mais tempo de empresa e dos 10 com menos tempo

# %%
display(base.nlargest(10, 'YearsAtCompany'))

display(base.nsmallest(10, 'YearsAtCompany'))
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 126    58       Yes  Travel_Rarely        147  Research & Development
# 98     58        No  Travel_Rarely        682                   Sales
# 270    55        No  Travel_Rarely        452  Research & Development
# 1116   55        No  Travel_Rarely        685                   Sales
# 561    52        No  Travel_Rarely        621                   Sales
# 190    52        No  Travel_Rarely        699  Research & Development
# 237    52        No     Non-Travel        771                   Sales
# 914    55        No     Non-Travel        177  Research & Development
# 962    51        No  Travel_Rarely        770         Human Resources
# 1111   53       Yes  Travel_Rarely        607  Research & Development
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 126                 23          4           Medical                        4
# ...

# %% [markdown]
# ## 10 funcionários com mais tempo no cargo (sem promoção) e dos 10 com menos tempo
#
# - Para esse tópico é relevante olhar:
#     - Age - espera-se pessoas com mais idade, pois tendem a ter mais tempo de cargo
#     - JobRole - Pode supor que chegou ao nivel de cargo mais alto
#
#
# ##### Cargos:
#
# - O Laboratory Technician chama atenção, precisando de mais detalhamento
#     - Podendo **cogitar** que a pessoa só se formou em técnico, sendo assim um fator para não ter tido promoção
# <br><br>
# - Para a pessoa de 59 anos com menos tempo, é interessante ver o tempo que está na empresa

# %%
display(base.nlargest(10, 'YearsSinceLastPromotion')[['Age', 'JobRole', 'YearsSinceLastPromotion', 'JobLevel']])

display(base.nsmallest(10, 'YearsSinceLastPromotion')[['Age', 'JobRole', 'YearsSinceLastPromotion', 'JobLevel']])
# Out:
#      Age                    JobRole  YearsSinceLastPromotion  JobLevel
# 45    41          Research Director                       15         5
# 123   51          Research Director                       15         5
# 126   58  Healthcare Representative                       15         3
# 178   46            Sales Executive                       15         3
# 237   52                    Manager                       15         5
# 425   50                    Manager                       15         4
# 701   53                    Manager                       15         4
# 752   36      Laboratory Technician                       15         1
# 861   46                    Manager                       15         4
# 914   55  Healthcare Representative                       15         4
#     Age                JobRole  YearsSinceLastPromotion  JobLevel
# 0    41        Sales Executive                        0         2
# ...

# %% [markdown]
# # Separando as colunas por tipo

# %%
base.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
col_nao_ordenada = [
    'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime'
]

col_ordenada = [
    'Education', 'JobSatisfaction', 'JobInvolvement', 'JobLevel', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
    'WorkLifeBalance'
]

col_alvo = ['Attrition']

col_numerica = [item for item in base.columns if item not in (col_nao_ordenada + col_ordenada + col_alvo)]

# %% [markdown]
# # Colunas categóricas

# %%
for col in (col_nao_ordenada + col_ordenada):
    print(f'{col}: {base[col].unique()}')
# Out:
# BusinessTravel: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department: ['Sales' 'Research & Development' 'Human Resources']
# EducationField: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender: ['Female' 'Male']
# JobRole: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# MaritalStatus: ['Single' 'Married' 'Divorced']
# OverTime: ['Yes' 'No']
# Education: [2 1 4 3 5]
# JobSatisfaction: [4 2 3 1]
# JobInvolvement: [3 2 4 1]
# JobLevel: [2 1 3 4 5]
# PerformanceRating: [3 4]
# RelationshipSatisfaction: [1 4 2 3]
# StockOptionLevel: [0 1 3 2]
# WorkLifeBalance: [1 3 2 4]

# %%
for col in col_nao_ordenada:
    base[col] = base[col].astype('category')

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
# ...

# %% [markdown]
# # Métodos do tipo Categórico
#
# ### Vantagens
#
# - Não faz categoria nos valores associados aos valores
# - Tem grande economia na memória do computador

# %%
base['OverTime'].cat.categories
# Out:
# Index(['No', 'Yes'], dtype='object')

# %%
base['OverTime'].cat.ordered
# Out:
# False

# %%
print(base['OverTime'], base['OverTime'].cat.codes)
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467    Yes
# 1468     No
# 1469     No
# Name: OverTime, Length: 1470, dtype: category
# Categories (2, object): ['No', 'Yes'] 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    1
# 1468    0
# 1469    0
# Length: 1470, dtype: int8

# %%
for col in base.select_dtypes(include='category'):
    print(col)
    print(f'{col}.cat.categories: {base[col].cat.categories}')
    print(f'{col}.cat.ordered: {base[col].cat.ordered}')
    print(f'{col}.cat.codes: {base[col].cat.codes.unique()}')
    print()
# Out:
# BusinessTravel
# BusinessTravel.cat.categories: Index(['Non-Travel', 'Travel_Frequently', 'Travel_Rarely'], dtype='object')
# BusinessTravel.cat.ordered: False
# BusinessTravel.cat.codes: [2 1 0]
#
# Department
# Department.cat.categories: Index(['Human Resources', 'Research & Development', 'Sales'], dtype='object')
# Department.cat.ordered: False
# Department.cat.codes: [2 1 0]
#
# EducationField
# EducationField.cat.categories: Index(['Human Resources', 'Life Sciences', 'Marketing', 'Medical', 'Other',
#        'Technical Degree'],
#       dtype='object')
# EducationField.cat.ordered: False
# EducationField.cat.codes: [1 4 3 2 5 0]
#
# Gender
# Gender.cat.categories: Index(['Female', 'Male'], dtype='object')
# Gender.cat.ordered: False
# Gender.cat.codes: [0 1]
#
# JobRole
# JobRole.cat.categories: Index(['Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
# ...

# %% [markdown]
# <br><br><br>
#
# # Agrupamentos
#
# <br><br>

# %%
# Muito mais não do que sim - Analise tedênciosa

print(base.Attrition.value_counts())

base.Attrition.value_counts(normalize=True).plot(kind='bar', color=['blue', 'red']);
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
base.Department.value_counts().plot(kind='bar', color=['blue', 'red', 'green']);

# %%
print(base.groupby(['Department', 'Attrition'], observed=True).size())

print('\n', '-' * 100, '\n')

print(base.pivot_table(index='Department', columns= 'Attrition', aggfunc='size', observed=True))
# Out:
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# dtype: int64
#
#  ----------------------------------------------------------------------------------------------------
#
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %% [markdown]
# <br><br>
#
# ##### O **crosstab** permite contar quantas vezes cada combinação de valores das variáveis ocorre no dataset. Útil para análise exploratória de dados, permitindo entender melhor a distribuição e a relação entre variáveis categóricas
#
# <br><br>

# %% [markdown]
# - CROSSTAB padrão

# %%
crosstab(base.Department, base.Attrition)
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %% [markdown]
# - CROSSTAB e variações:
#
#     - **normalize:** É para definir o percentual representativo, se será para cada item do index, ou para as colunas
#     - **style:** Definir um estilo para o DataFrame com o matplotlib
#     - **margins:** Coolocar o total somado para as linhas e colunas

# %%
print('\nPercentual por linhas (index) - Department\n')
display(crosstab(base.Department, base.Attrition, normalize='index').style.background_gradient(cmap='RdYlGn', axis='columns'))

print('\nPercentual por Coluna (columns) - Attrition\n')
display(crosstab(base.Department, base.Attrition, normalize='columns').style.background_gradient(cmap='RdYlGn', axis='columns'))
# Out:
# Percentual por linhas (index) - Department
# <style type="text/css">
# #T_1f476_row0_col0, #T_1f476_row1_col0, #T_1f476_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1f476_row0_col1, #T_1f476_row1_col1, #T_1f476_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1f476">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_1f476_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_1f476_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f476_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_1f476_row0_col0" class="data row0 col0" >0.809524</td>
# ...

# %%
crosstab(base.Department, base.Attrition, margins=True, margins_name='Total')
# Out:
# Attrition                 No  Yes  Total
# Department
# Human Resources           51   12     63
# Research & Development   828  133    961
# Sales                    354   92    446
# Total                   1233  237   1470

# %%
crosstab(base.Department, base.Attrition).plot(kind='bar');

# %% [markdown]
# <br><br><br>
#
# ## Analisar sálario por departamento
#
# <br><br><br>

# %%
base.groupby('Department', observed=True).MonthlyIncome.mean().plot(kind='bar');

# %%
# GROUPBY

# Considerando apenas a média, o possivel motivo para as pessoas sairem da empresa é o salário - Tendo uma média menor

base.groupby(['Department', 'Attrition'], observed=True).MonthlyIncome.mean()
# Out:
# Department              Attrition
# Human Resources         No          7_345.98
#                         Yes         3_715.75
# Research & Development  No          6_630.33
#                         Yes         4_108.08
# Sales                   No          7_232.24
#                         Yes         5_908.46
# Name: MonthlyIncome, dtype: float64

# %%
# PIVOT_TABLE

# Considerando apenas a média, o possivel motivo para as pessoas sairem da empresa é o salário - Tendo uma média menor

base.pivot_table(index='Department', columns='Attrition', values='MonthlyIncome', observed=True).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
# PIVOT_TABLE

# Considerando apenas a média, o possivel motivo para as pessoas sairem da empresa é o salário - Tendo uma média menor

base.pivot_table(index='JobRole', columns='Attrition', values='MonthlyIncome', observed=True).plot(kind='bar')
# Out:
# <Axes: xlabel='JobRole'>

# %% [markdown]
# <br><br><br>
#
# ## Análise:
#
# #### É possível fazer a correlação do Salário (MonthlyIncome) com o cargo (JobRole) e nivel com o Atrito (Attriction), representando que a área de vendas (Sales) tem maior atrito
#
# <br>
#
#
# - Tendo uma **possível** explicação, até por não tem mais niveis no cargo, que não tenha um bom nivel de carreira
#
# - Sempre anaisando possibilidades, até comprovar o resultado

# %%
display(base.pivot_table(index=['JobRole', 'JobLevel'], values='MonthlyIncome', observed=True).\
                style.background_gradient(cmap='YlGn', axis=0))


print('\nPercentual por Linha (Index) - Attrition\n')
display(crosstab(base.Department, base.Attrition, normalize='index').style.background_gradient(cmap='YlGn', axis='columns'))
# Out:
# <style type="text/css">
# #T_94eaa_row0_col0 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_94eaa_row1_col0 {
#   background-color: #9dd688;
#   color: #000000;
# }
# #T_94eaa_row2_col0 {
#   background-color: #40aa5c;
#   color: #f1f1f1;
# }
# #T_94eaa_row3_col0 {
#   background-color: #feffe1;
#   color: #000000;
# }
# #T_94eaa_row4_col0 {
#   background-color: #eaf7af;
#   color: #000000;
# }
# #T_94eaa_row5_col0 {
#   background-color: #97d385;
#   color: #000000;
# }
# #T_94eaa_row6_col0 {
#   background-color: #feffde;
#   color: #000000;
# }
# #T_94eaa_row7_col0 {
#   background-color: #f8fcbd;
#   color: #000000;
# }
# #T_94eaa_row8_col0 {
#   background-color: #e3f4aa;
#   color: #000000;
# }
# #T_94eaa_row9_col0 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_94eaa_row10_col0 {
#   background-color: #086e3a;
#   color: #f1f1f1;
# }
# #T_94eaa_row11_col0, #T_94eaa_row17_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# <br><br><br><br>
#
# ### Olhando para o campo Attriction - sendo a coluna alvo
#
# <br>

# %% [markdown]
# - Tem que fazer um levantamento e comparativo com o total de pessoas da base, como por exemplo:
#     - Human Resouces, tem poucas pessoas com atrito, por tanto precisa de uma analise
#         -  Podem ser exessões

# %%
display(crosstab([base.JobRole, base.JobLevel], base.Attrition, values=base.MonthlyIncome, aggfunc='mean')\
            .style.background_gradient(cmap='YlGn', axis='columns'))

display(crosstab(base.Department, base.Attrition, margins=True, margins_name='Total'))
# Out:
# <style type="text/css">
# #T_0a753_row0_col0, #T_0a753_row1_col1, #T_0a753_row2_col1, #T_0a753_row3_col1, #T_0a753_row4_col0, #T_0a753_row4_col1, #T_0a753_row5_col0, #T_0a753_row6_col1, #T_0a753_row7_col0, #T_0a753_row8_col1, #T_0a753_row9_col0, #T_0a753_row10_col0, #T_0a753_row10_col1, #T_0a753_row11_col0, #T_0a753_row12_col1, #T_0a753_row13_col0, #T_0a753_row14_col0, #T_0a753_row14_col1, #T_0a753_row15_col0, #T_0a753_row15_col1, #T_0a753_row16_col0, #T_0a753_row16_col1, #T_0a753_row17_col0, #T_0a753_row18_col1, #T_0a753_row19_col1, #T_0a753_row20_col0, #T_0a753_row20_col1, #T_0a753_row21_col0, #T_0a753_row22_col0, #T_0a753_row23_col0, #T_0a753_row24_col1, #T_0a753_row25_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# ...

# %%
display(crosstab([base.JobRole, base.JobLevel], base.Attrition, values=base.MonthlyIncome, aggfunc=['mean', 'size'])\
            .dropna(how='all', subset=[('mean', 'No'), ('mean', 'Yes')])\
            .style.background_gradient(cmap='YlGn', axis='columns'))

display(crosstab(base.Department, base.Attrition, margins=True, margins_name='Total'))
# Out:
# <style type="text/css">
# #T_346b5_row0_col0 {
#   background-color: #056c39;
#   color: #f1f1f1;
# }
# #T_346b5_row0_col1, #T_346b5_row1_col0, #T_346b5_row2_col0, #T_346b5_row3_col0, #T_346b5_row4_col0, #T_346b5_row5_col1, #T_346b5_row6_col0, #T_346b5_row7_col1, #T_346b5_row8_col0, #T_346b5_row9_col1, #T_346b5_row10_col0, #T_346b5_row11_col1, #T_346b5_row12_col0, #T_346b5_row13_col1, #T_346b5_row14_col0, #T_346b5_row15_col0, #T_346b5_row16_col0, #T_346b5_row17_col1, #T_346b5_row18_col0, #T_346b5_row19_col0, #T_346b5_row20_col0, #T_346b5_row21_col1, #T_346b5_row22_col1, #T_346b5_row23_col1, #T_346b5_row24_col0, #T_346b5_row25_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_346b5_row0_col2, #T_346b5_row7_col2, #T_346b5_row19_col2 {
#   background-color: #feffe2;
#   color: #000000;
# }
# ...

# %% [markdown]
# - Analisando números relativos

# %%
crosstab([base.JobRole, base.JobLevel], base.Attrition, normalize='index')\
            .style.background_gradient(cmap='YlGn', axis='columns', vmin=0, vmax=1)
# Out:
# <style type="text/css">
# #T_47c52_row0_col0 {
#   background-color: #004f2d;
#   color: #f1f1f1;
# }
# #T_47c52_row0_col1 {
#   background-color: #fdfed9;
#   color: #000000;
# }
# #T_47c52_row1_col0 {
#   background-color: #006536;
#   color: #f1f1f1;
# }
# #T_47c52_row1_col1 {
#   background-color: #f8fcbd;
#   color: #000000;
# }
# #T_47c52_row2_col0, #T_47c52_row13_col0 {
#   background-color: #006435;
#   color: #f1f1f1;
# }
# #T_47c52_row2_col1, #T_47c52_row13_col1 {
#   background-color: #f8fcbe;
#   color: #000000;
# }
# #T_47c52_row3_col0 {
#   background-color: #2f944e;
#   color: #f1f1f1;
# }
# #T_47c52_row3_col1 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_47c52_row4_col0, #T_47c52_row10_col0, #T_47c52_row14_col0, #T_47c52_row15_col0, #T_47c52_row16_col0, #T_47c52_row20_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# <br><br><br>
#
# # Analisando Genêro
#
# <br><br>

# %% [markdown]
# - Mais masculino do que feminino

# %%
crosstab([base.Department, base.Attrition], base.Gender, margins=True)
# Out:
# Gender                            Female  Male   All
# Department             Attrition
# Human Resources        No             14    37    51
#                        Yes             6     6    12
# Research & Development No            336   492   828
#                        Yes            43    90   133
# Sales                  No            151   203   354
#                        Yes            38    54    92
# All                                  588   882  1470

# %% [markdown]
# - Genêro por cargo

# %%
display(crosstab([base.JobRole, base.Gender], base.Attrition, margins=True))
# Out:
# Attrition                           No  Yes   All
# JobRole                   Gender
# Healthcare Representative Female    46    5    51
#                           Male      76    4    80
# Human Resources           Female    10    6    16
#                           Male      30    6    36
# Laboratory Technician     Female    69   16    85
#                           Male     128   46   174
# Manager                   Female    45    2    47
#                           Male      52    3    55
# Manufacturing Director    Female    68    4    72
#                           Male      67    6    73
# Research Director         Female    32    1    33
#                           Male      46    1    47
# Research Scientist        Female    97   17   114
#                           Male     148   30   178
# Sales Executive           Female   112   20   132
#                           Male     157   37   194
# Sales Representative      Female    22   16    38
# ...

# %% [markdown]
# <br><br><br>
#
# # Analisando Nivel Educacional
#
# <br><br>

# %%
display(base.groupby('Education').MonthlyIncome.mean())

map_education = {
    1: 'Below College', 2: 'College', 3: 'Bachelor', 4: 'Master', 5: 'PhD'
}
print('\n','\nMédia salarial por grau de educação')

display(base.groupby('Education').MonthlyIncome.mean().rename(index=map_education))

print('\n','\nQuantidade de pessoas com grau de educação')

display(base.groupby('Education').size().rename(index=map_education))
# Out:
# Education
# 1   5_640.57
# 2   6_226.65
# 3   6_517.26
# 4   6_832.40
# 5   8_277.65
# Name: MonthlyIncome, dtype: float64
#
# Média salarial por grau de educação
# Education
# Below College   5_640.57
# College         6_226.65
# Bachelor        6_517.26
# Master          6_832.40
# PhD             8_277.65
# Name: MonthlyIncome, dtype: float64
#
# Quantidade de pessoas com grau de educação
# Education
# Below College    170
# College          282
# Bachelor         572
# Master           398
# PhD               48
# dtype: int64

# %%
print('\nQuantidade de pessoas por nivel educacional')
display(crosstab(base.Education, base.Attrition, margins=True).rename(index=map_education))
display(crosstab(base.Education, base.Attrition, margins=True, normalize='index').rename(index=map_education))
display(crosstab(base.Education, base.Department, margins=True, normalize='index').rename(index=map_education))
print('\nAnalisando nivel eduacacional por Cargo - Concentração de Nivel\n\nComparando com a tabela de baixo - Concentracao por Cargo\n')
display(crosstab(base.Education, base.JobRole, margins=True, normalize='index').rename(index=map_education).mul(100).round(2))
display(crosstab(base.Education, base.JobRole, margins=True, normalize='columns').rename(index=map_education).mul(100).round(2))
print('\nAnalisando nivel eduacacional por Nivel de Cargo - Concentração de Nivel Educacional')
display(crosstab(base.Education, base.JobLevel, margins=True, normalize='index').rename(index=map_education).mul(100).round(2))
display(crosstab([base.JobRole, base.JobLevel, base.Attrition], base.Education, margins=True).rename(columns=map_education))
# Out:
# Quantidade de pessoas por nivel educacional
# Attrition        No  Yes   All
# Education
# Below College   139   31   170
# College         238   44   282
# Bachelor        473   99   572
# Master          340   58   398
# PhD              43    5    48
# All            1233  237  1470
# Attrition       No  Yes
# Education
# Below College 0.82 0.18
# College       0.84 0.16
# Bachelor      0.83 0.17
# Master        0.85 0.15
# PhD           0.90 0.10
# All           0.84 0.16
# Department     Human Resources  Research & Development  Sales
# Education
# Below College             0.03                    0.68   0.29
# College                   0.05                    0.65   0.31
# Bachelor                  0.05                    0.66   0.29
# Master                    0.04                    0.64   0.32
# PhD                       0.06                    0.62   0.31
# All                       0.04                    0.65   0.30
# ...

# %% [markdown]
# ## Noções de estatística

# %% [markdown]
# ### Histogramas
#
# Um histograma é uma representação visual da distribuição de dados quantitativos. Para construir um histograma, o primeiro passo é agrupar o intervalo de valores - dividir todo o intervalo de valores em uma série de intervalos - e depois contar quantos valores caem em cada intervalo. Os intervalos (*bins*, em inglês) são geralmente especificados como intervalos consecutivos e não sobrepostos de uma variável. Os bins devem ser adjacentes e geralmente (mas não são obrigados a ser) de tamanho igual.
#
# Os histogramas dão uma ideia aproximada da densidade da distribuição subjacente dos dados e muitas vezes para a estimativa de densidade, ou seja estimar a probabilidade da variável subjacente.
#
# #### Histogramas vs gráfico de barras
#
# Os histogramas são às vezes confundidos com gráficos de barras. Um histograma é usado para dados quantitativos, onde os bins representam intervalos de valores, enquanto um gráfico de barras é um gráfico de variáveis categóricas.
#
# Um gráfico de barras é um gráfico que usa barras para representar a frequência ou quantidade de diferentes categorias de dados.
#
# Um histograma, por outro lado, é um gráfico que mostra a distribuição de dados numéricos. É um tipo de gráfico de barras que mostra a frequência ou número de observações dentro de diferentes intervalos numéricos, chamados de bins. Os bins são geralmente especificados como intervalos consecutivos e não sobrepostos de uma variável. O histograma fornece uma representação visual da distribuição dos dados, mostrando o número de observações que caem em cada bin. Isso pode ser útil para identificar padrões e tendências nos dados e para fazer comparações entre diferentes conjuntos de dados.

# %%
display(base.groupby('Gender', observed=True).size())

print()

display(base.groupby('Gender', observed=True).Age.mean())


print()

display(base.groupby('Gender', observed=True).Age.plot(kind='hist', legend=True, alpha=0.5))
# Out:
# Gender
# Female    588
# Male      882
# dtype: int64
# Gender
# Female   37.33
# Male     36.65
# Name: Age, dtype: float64
# Gender
# Female    Axes(0.125,0.11;0.775x0.77)
# Male      Axes(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object

# %% [markdown]
# # Aplicando o hist de uma melhor forma
#
# - **BY:** Representa o mesmo que o groupby(item)
# - **SHAREY:** Para compartilhar o mesmo y

# %%
print('\n\nMelhor vizualização\n\n')

temp = base.copy()
temp.Gender = temp.Gender.astype(object)
temp.hist(column='Age', by='Gender', sharey=True, figsize=(15, 4));
# Out:
# Melhor vizualização

# %%
base.groupby('Attrition').Age.value_counts(bins=10)
# Out:
# Attrition  Age
# No         (34.8, 39.0]                  267
#            (30.6, 34.8]                  215
#            (26.4, 30.6]                  180
#            (39.0, 43.2]                  160
#            (43.2, 47.4]                  116
#            (47.4, 51.6]                   81
#            (22.2, 26.4]                   76
#            (51.6, 55.8]                   69
#            (55.8, 60.0]                   39
#            (17.956999999999997, 22.2]     30
# Yes        (30.0, 34.0]                   50
#            (26.0, 30.0]                   44
#            (22.0, 26.0]                   29
#            (17.959, 22.0]                 27
#            (34.0, 38.0]                   24
#            (38.0, 42.0]                   19
#            (42.0, 46.0]                   14
#            (46.0, 50.0]                   12
#            (54.0, 58.0]                   11
#            (50.0, 54.0]                    7
# Name: count, dtype: int64
